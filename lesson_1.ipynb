# %%
import numpy as np

# %%
a = np.array([[5, 10],
              [7, 12],
              [11.3, 5],
              [25, 30]])

print(7*a+2*a)
# Out:
# [[ 45.   90. ]
#  [ 63.  108. ]
#  [101.7  45. ]
#  [225.  270. ]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x=np.arange(0, 10, 0.1)
k1=1
k2=3
plt.plot(x, np.cos(k1*x))
plt.plot(x, np.cos(k2*x))
